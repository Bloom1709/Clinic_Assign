# %% [markdown]
# # ชื่อ : ณัฐกานต์
# # นามสกุล : ศิริพรโณ
# # รหัสนักศึกษา : 61070290

# %% [markdown]
# # Lab AI for Medicine : Heart Dataset
# ชุดข้อมูลโรคหัวใจ ประกอบด้วยฐานข้อมูล 4 ฐานข้อมูลเกี่ยวกับการวินิจฉัยโรคหัวใจ แอตทริบิวต์ทั้งหมดมีค่าเป็นตัวเลข ข้อมูลถูกรวบรวมจากไฟล์  4 สถานที่ดังต่อไปนี้:
#
#       1 มูลนิธิคลีฟแลนด์คลินิก (cleveland.data)
#       2 สถาบันโรคหัวใจแห่งฮังการีบูดาเปสต์ (Hungarian.data)
#       3 V.A. ศูนย์การแพทย์ลองบีชแคลิฟอร์เนีย (long-beach-va.data)
#       4 โรงพยาบาลมหาวิทยาลัยซูริกประเทศสวิตเซอร์แลนด์ (ข้อมูลสวิตเซอร์แลนด์)
#
# แต่ละฐานข้อมูลมีรูปแบบเดียวกัน ในขณะที่ฐานข้อมูลมี 76 แอตทริบิวต์ มีเพียง 14 รายการเท่านั้นที่ใช้จริง
#
# ข้อมูลโรคหัวใจชุดนี้มี 76 แอตทริบิวต์ ซึ่งมีรายละเอียดดังนี้
#
# 1 id: patient identification number
#
# 2 ccf: social security number (I replaced this with a dummy value of 0)
#
# 3 age: age in years
#
# 4 sex: sex (1 = male; 0 = female)
#
# 5 painloc: chest pain location (1 = substernal; 0 = otherwise)
#
# 6 painexer (1 = provoked by exertion; 0 = otherwise)
#
# 7 relrest (1 = relieved after rest; 0 = otherwise)
#
# 8 pncaden (sum of 5, 6, and 7)
#
# 9 cp: chest pain type
# -- Value 1: typical angina
# -- Value 2: atypical angina
# -- Value 3: non-anginal pain
# -- Value 4: asymptomatic
#
# 10 trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#
# 11 htn
#
# 12 chol: serum cholestoral in mg/dl
#
# 13 smoke: I believe this is 1 = yes; 0 = no (is or is not a smoker)
#
# 14 cigs (cigarettes per day)
#
# 15 years (number of years as a smoker)
#
# 16 fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
# 17 dm (1 = history of diabetes; 0 = no such history)
#
# 18 famhist: family history of coronary artery disease (1 = yes; 0 = no)
#
# 19 restecg: resting electrocardiographic results
# -- Value 0: normal
# -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# 20 ekgmo (month of exercise ECG reading)
#
# 21 ekgday(day of exercise ECG reading)
#
# 22 ekgyr (year of exercise ECG reading)
#
# 23 dig (digitalis used furing exercise ECG: 1 = yes; 0 = no)
#
# 24 prop (Beta blocker used during exercise ECG: 1 = yes; 0 = no)
#
# 25 nitr (nitrates used during exercise ECG: 1 = yes; 0 = no)
#
# 26 pro (calcium channel blocker used during exercise ECG: 1 = yes; 0 = no)
#
# 27 diuretic (diuretic used used during exercise ECG: 1 = yes; 0 = no)
#
# 28 proto: exercise protocol
#   1 = Bruce
#   2 = Kottus
#   3 = McHenry
#   4 = fast Balke
#   5 = Balke
#   6 = Noughton
#   7 = bike 150 kpa min/min (Not sure if "kpa min/min" is what was written!)
#   8 = bike 125 kpa min/min
#   9 = bike 100 kpa min/min
#   10 = bike 75 kpa min/min
#   11 = bike 50 kpa min/min
#   12 = arm ergometer
#
# 29 thaldur: duration of exercise test in minutes
#
# 30 thaltime: time when ST measure depression was noted
#
# 31 met: mets achieved
#
# 32 thalach: maximum heart rate achieved
#
# 33 thalrest: resting heart rate
#
# 34 tpeakbps: peak exercise blood pressure (first of 2 parts)
#
# 35 tpeakbpd: peak exercise blood pressure (second of 2
# parts)
#
# 36 dummy
#
# 37 trestbpd: resting blood pressure
#
# 38 exang: exercise induced angina (1 = yes; 0 = no)
#
# 39 xhypo: (1 = yes; 0 = no)
#
# 40 oldpeak = ST depression induced by exercise relative to rest
#
# 41 slope: the slope of the peak exercise ST segment
# -- Value 1: upsloping
# -- Value 2: flat
# -- Value 3: downsloping
#
# 42 rldv5: height at rest
#
# 43 rldv5e: height at peak exercise
#
# 44 ca: number of major vessels (0-3) colored by flourosopy
#
# 45 restckm: irrelevant
#
# 46 exerckm: irrelevant
#
# 47 restef: rest raidonuclid (sp?) ejection fraction
#
# 48 restwm: rest wall (sp?) motion abnormality
#   0 = none
#   1 = mild or moderate
#   2 = moderate or severe
#   3 = akinesis or dyskmem (sp?)
#
# 49 exeref: exercise radinalid (sp?) ejection fraction
#
# 50 exerwm: exercise wall (sp?) motion
#
# 51 thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#
# 52 thalsev: not used
#
# 53 thalpul: not used
#
# 54 earlobe: not used
#
# 55 cmo: month of cardiac cath (sp?) (perhaps "call")
#
# 56 cday: day of cardiac cath (sp?)
#
# 57 cyr: year of cardiac cath (sp?)
#
# 58 num: diagnosis of heart disease (angiographic disease status)
# -- Value 0: < 50% diameter narrowing
# -- Value 1: > 50% diameter narrowing
# (in any major vessel: attributes 59 through 68 are vessels)
#
# 59 lmt
#
# 60 ladprox
#
# 61 laddist
#
# 62 diag
#
# 63 cxmain
#
# 64 ramus
#
# 65 om1
#
# 66 om2
#
# 67 rcaprox
#
# 68 rcadist
#
# 69 lvx1: not used
#
# 70 lvx2: not used
#
# 71 lvx3: not used
#
# 72 lvx4: not used
#
# 73 lvf: not used
#
# 74 cathef: not used
#
# 75 junk: not used
#
# 76 name: last name of patient (I replaced this with the dummy string "name")

# %% [markdown]
# จำนวนข้อมูลโรคหัวใจมีดังนี้ :
#
# *   Cleveland     :     303 Records
# *   Hungarian     :     294 Records
# *   Switzerland   :     123 Records
# *   Long Beach VA :     200 Records

# %% [markdown]
# Attribute Information:
#    -- Only 14 used
#
#       -- 1. #3  (age)
#       -- 2. #4  (sex)
#       -- 3. #9  (cp)
#       -- 4. #10 (trestbps)
#       -- 5. #12 (chol)
#       -- 6. #16 (fbs)
#       -- 7. #19 (restecg)
#       -- 8. #32 (thalach)
#       -- 9. #38 (exang)
#       -- 10. #40 (oldpeak)
#       -- 11. #41 (slope)
#       -- 12. #44 (ca)
#       -- 13. #51 (thal)
#       -- 14. #58 (num)       (the predicted attribute)

# %% [markdown]
# # วัตถุประสงค์

# %% [markdown]
# โครงการนี้มีวัตถุประสงค์เพื่อช่วยให้ผู้เชี่ยวชาญด้านสุขภาพทำการวินิจฉัยได้ง่ายขึ้นโดยใช้เทคนิค Machine Learning เพื่อเป็นการเชื่อมกันระหว่างความรู้กับชุดข้อมูลที่ทำการบันทึกไว้สามารถนำไปใช้ประโยขน์ได้ ดังนั้นในการทดลองนี้เราจะนำเทคนิค Machine learning มาประยุกต์ใช้กับ Heart Dataset

# %% [markdown]
# Import and Loading Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn.model_selection as mod
import sklearn.neighbors as nei
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report, precision_recall_curve, average_precision_score 
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFECV
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import operator
# %matplotlib inline
import matplotlib
from matplotlib import pyplot
from sklearn import preprocessing
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2 as sklearn_chi2


from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
import h5py
from sklearn.metrics import recall_score, precision_score,f1_score
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# %%
df = pd.read_csv('Heart_UCI_data/Processed_switzerland_data.csv')
df
# Out:
#      Age  Sex  Chest pain type Trestbps  Chol Fbs Restecg Thalach Exang Oldpeak Slope Ca Thal  Num_diagnosis
# 0     32    1                1       95     0   ?       0     127     0     0.7     1  ?    ?              1
# 1     34    1                4      115     0   ?       ?     154     0     0.2     1  ?    ?              1
# 2     35    1                4        ?     0   ?       0     130     1       ?     ?  ?    7              3
# 3     36    1                4      110     0   ?       0     125     1       1     2  ?    6              1
# 4     38    0                4      105     0   ?       0     166     0     2.8     1  ?    ?              2
# 5     38    0                4      110     0   0       0     156     0       0     2  ?    3              1
# 6     38    1                3      100     0   ?       0     179     0    -1.1     1  ?    ?              0
# 7     38    1                3      115     0   0       0     128     1       0     2  ?    7              1
# 8     38    1                4      135     0   ?       0     150     0       0     ?  ?    3              2
# 9     38    1                4      150     0   ?       0     120     1       ?     ?  ?    3              1
# 10    40    1                4       95     0   ?       1     144     0       0     1  ?    ?              2
# 11    41    1                4      125     0   ?       0     176     0     1.6     1  ?    ?              2
# 12    42    1                4      105     0   ?       0     128     1    -1.5     3  ?    ?              1
# 13    42    1                4      145     0   0       0      99     1       0     2  ?    ?              2
# 14    43    1                4      100     0   ?       0     122     0     1.5     3  ?    ?              3
# 15    43    1                4      115     0   0       0     145     1       2     2  ?    7              4
# 16    43    1                4      140     0   0       1     140     1     0.5     1  ?    7              2
# 17    45    1                3      110     0   ?       0     138     0    -0.1     1  ?    ?              0
# 18    46    1                4      100     0   ?       1     133     0    -2.6     2  ?    ?              1
# 19    46    1                4      115     0   0       0     113     1     1.5     2  ?    7              1
# 20    47    1                3      110     0   ?       0     120     1       0     ?  ?    3              1
# 21    47    1                3      155     0   0       0     118     1       1     2  ?    3              3
# 22    47    1                4      110     0   ?       1     149     0     2.1     1  ?    ?              2
# 23    47    1                4      160     0   0       0     124     1       0     2  ?    7              1
# 24    48    1                4      115     0   ?       0     128     0       0     2  ?    6              2
# 25    50    0                4      160     0   ?       0     110     0       0     ?  ?    3              1
# 26    50    1                4      115     0   0       0     120     1     0.5     2  ?    6              3
# 27    50    1                4      120     0   0       1     156     1       0     1  ?    6              3
# 28    50    1                4      145     0   ?       0     139     1     0.7     2  ?    ?              1
# 29    51    0                4      120     0   ?       0     127     1     1.5     1  ?    ?              2
# 30    51    1                4      110     0   ?       0      92     0       0     2  ?    ?              4
# 31    51    1                4      120     0   1       0     104     0       0     2  ?    3              3
# 32    51    1                4      130     0   ?       0     170     0    -0.7     1  ?    ?              2
# 33    51    1                4      130     0   ?       1     163     0       0     ?  ?    7              1
# 34    51    1                4      140     0   0       0      60     0       0     2  ?    3              2
# 35    51    1                4       95     0   ?       0     126     0     2.2     2  ?    ?              2
# 36    52    1                4      130     0   ?       0     120     0       0     2  ?    7              2
# 37    52    1                4      135     0   ?       0     128     1       2     2  ?    7              2
# 38    52    1                4      165     0   ?       0     122     1       1     1  ?    7              2
# 39    52    1                4       95     0   ?       0      82     1       ?     ?  ?    ?              2
# 40    53    1                2      120     0   0       0      95     0       0     2  ?    3              3
# 41    53    1                2      130     0   ?       1     120     0     0.7     3  ?    ?              0
# 42    53    1                3      105     0   0       0     115     0       0     2  ?    7              1
# 43    53    1                3      160     0   ?       2     122     1       0     ?  ?    7              1
# 44    53    1                4      120     0   ?       0     120     0       0     2  ?    7              1
# 45    53    1                4      125     0   ?       0     120     0     1.5     1  ?    ?              4
# 46    53    1                4      130     0   0       2     135     1       1     2  ?    7              2
# 47    53    1                4       80     0   ?       0     141     1       2     3  ?    ?              0
# 48    54    1                4      120     0   0       0     155     0       0     2  ?    7              2
# 49    54    1                4      130     0   ?       0     110     1       3     2  ?    7              3
# 50    54    1                4      180     0   ?       0     150     0     1.5     2  ?    7              1
# 51    55    1                2      140     0   ?       1     150     0     0.2     1  ?    ?              0
# 52    55    1                4      115     0   ?       0     155     0     0.1     2  ?    ?              1
# 53    55    1                4      120     0   0       1      92     0     0.3     1  ?    7              4
# 54    55    1                4      140     0   0       0      83     0       0     2  ?    7              2
# 55    56    1                3      120     0   0       0      97     0       0     2  ?    7              0
# 56    56    1                3      125     0   ?       0      98     0      -2     2  ?    7              2
# 57    56    1                3      155     0   0       1      99     0       0     2  ?    3              2
# 58    56    1                4      115     0   ?       1      82     0      -1     1  ?    ?              1
# 59    56    1                4      120     0   0       1     100     1      -1     3  ?    7              2
# 60    56    1                4      120     0   0       1     148     0       0     2  ?    ?              2
# 61    56    1                4      125     0   1       0     103     1       1     2  ?    7              3
# 62    56    1                4      140     0   ?       0     121     1     1.8     1  ?    ?              1
# 63    57    1                3      105     0   ?       0     148     0     0.3     2  ?    ?              1
# 64    57    1                4      110     0   ?       1     131     1     1.4     1  1    ?              3
# 65    57    1                4      140     0   0       0     120     1       2     2  ?    6              2
# 66    57    1                4      140     0   ?       0     100     1       0     ?  ?    6              3
# 67    57    1                4      160     0   ?       0      98     1       2     2  ?    7              2
# 68    57    1                4       95     0   ?       0     182     0     0.7     3  ?    ?              1
# 69    58    1                4      115     0   ?       0     138     0     0.5     1  ?    ?              1
# 70    58    1                4      130     0   0       1     100     1       1     2  ?    6              4
# 71    58    1                4      170     0   ?       1     105     1       0     ?  ?    3              1
# 72    59    1                3      125     0   ?       0     175     0     2.6     2  ?    ?              1
# 73    59    1                4      110     0   ?       0      94     0       0     ?  ?    6              3
# 74    59    1                4      120     0   0       0     115     0       0     2  ?    3              2
# 75    59    1                4      125     0   ?       0     119     1     0.9     1  ?    ?              1
# 76    59    1                4      135     0   0       0     115     1       1     2  ?    7              1
# 77    60    1                3      115     0   ?       0     143     0     2.4     1  ?    ?              1
# 78    60    1                4      125     0   ?       0     110     0     0.1     1  2    ?              3
# 79    60    1                4      130     0   ?       1     130     1     1.1     3  1    ?              1
# 80    60    1                4      135     0   0       0      63     1     0.5     1  ?    7              3
# 81    60    1                4      160     0   0       1      99     1     0.5     2  ?    7              3
# 82    60    1                4      160     0   ?       0     149     0     0.4     2  ?    ?              1
# 83    61    1                3      200     0   ?       1      70     0       0     ?  ?    3              3
# 84    61    1                4      105     0   ?       0     110     1     1.5     1  ?    ?              1
# 85    61    1                4      110     0   ?       0     113     0     1.4     2  ?    ?              1
# 86    61    1                4      125     0   0       0     105     1       0     3  ?    7              3
# 87    61    1                4      130     0   0       2     115     0       0     2  ?    7              3
# 88    61    1                4      130     0   ?       0      77     0     2.5     2  ?    ?              3
# 89    61    1                4      150     0   0       0     105     1       0     2  ?    7              1
# 90    61    1                4      150     0   0       0     117     1       2     2  ?    7              2
# 91    61    1                4      160     0   1       1     145     0       1     2  ?    7              2
# 92    62    0                1      140     0   ?       0     143     0       0     ?  ?    3              2
# 93    62    0                4      120     0   ?       1     123     1     1.7     3  ?    ?              1
# 94    62    1                1      120     0   ?       2     134     0    -0.8     2  2    ?              1
# 95    62    1                3      160     0   0       0      72     1       0     2  ?    3              3
# 96    62    1                4      115     0   ?       0     128     1     2.5     3  ?    ?              2
# 97    62    1                4      115     0   ?       0      72     1    -0.5     2  ?    3              1
# 98    62    1                4      150     0   ?       1      78     0       2     2  ?    7              3
# 99    63    1                4      100     0   ?       0     109     0    -0.9     2  ?    ?              1
# 100   63    1                4      140     0   ?       2     149     0       2     1  ?    ?              2
# 101   63    1                4      150     0   0       0      86     1       2     2  ?    ?              3
# 102   63    1                4      150     0   ?       1     154     0     3.7     1  ?    ?              3
# 103   63    1                4      185     0   0       0      98     1       0     1  ?    7              1
# 104   64    0                4      200     0   0       0     140     1       1     2  ?    3              3
# 105   64    0                4       95     0   ?       0     145     0     1.1     3  ?    ?              1
# 106   64    1                4      110     0   ?       0     114     1     1.3     3  ?    ?              1
# 107   65    1                4      115     0   0       0      93     1       0     2  ?    7              1
# 108   65    1                4      145     0   ?       1      67     0       ?     ?  ?    6              3
# 109   65    1                4      155     0   ?       0     154     0       1     1  ?    ?              0
# 110   65    1                4      160     0   1       1     122     0       ?     ?  ?    7              3
# 111   66    0                4      155     0   ?       0      90     0       0     ?  ?    7              1
# 112   66    1                4      150     0   0       0     108     1       2     2  ?    7              3
# 113   67    1                1      145     0   0       2     125     0       0     2  ?    3              2
# 114   68    1                4      135     0   0       1     120     1       0     1  ?    7              3
# 115   68    1                4      145     0   ?       0     136     0     1.8     1  ?    ?              1
# 116   69    1                4      135     0   0       0     130     0       0     2  ?    6              1
# 117   69    1                4        ?     0   0       1       ?     ?       ?     ?  ?    7              3
# 118   70    1                4      115     0   0       1      92     1       0     2  ?    7              1
# 119   70    1                4      140     0   1       0     157     1       2     2  ?    7              3
# 120   72    1                3      160     0   ?       2     114     0     1.6     2  2    ?              0
# 121   73    0                3      160     0   0       1     121     0       0     1  ?    3              1
# 122   74    1                2      145     0   ?       1     123     0     1.3     1  ?    ?              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              123 non-null    int64
#  1   Sex              123 non-null    int64
#  2   Chest pain type  123 non-null    int64
#  3   Trestbps         123 non-null    object
#  4   Chol             123 non-null    int64
#  5   Fbs              123 non-null    object
#  6   Restecg          123 non-null    object
#  7   Thalach          123 non-null    object
#  8   Exang            123 non-null    object
#  9   Oldpeak          123 non-null    object
#  10  Slope            123 non-null    object
#  11  Ca               123 non-null    object
#  12  Thal             123 non-null    object
#  13  Num_diagnosis    123 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 13.6+ KB

# %% [markdown]
# # Check Null Value

# %%
df.isnull().sum()
# Out:
# Age                0
# Sex                0
# Chest pain type    0
# Trestbps           0
# Chol               0
# Fbs                0
# Restecg            0
# Thalach            0
# Exang              0
# Oldpeak            0
# Slope              0
# Ca                 0
# Thal               0
# Num_diagnosis      0
# dtype: int64

# %% [markdown]
# # ตรวจสอบข้อมูลเพื่อจัดการ Missing Data

# %%
df = df.replace("?", np.NaN)
df.isnull().sum()
# Out:
# Age                  0
# Sex                  0
# Chest pain type      0
# Trestbps             2
# Chol                 0
# Fbs                 75
# Restecg              1
# Thalach              1
# Exang                1
# Oldpeak              6
# Slope               17
# Ca                 118
# Thal                52
# Num_diagnosis        0
# dtype: int64

# %%
for i in df.columns:
    if (df[i].isnull().sum())/df[i].count()*100 >= (df[i].count()*(30/100)) or df[i].value_counts().count() == 1 :
        df.drop([i], axis='columns', inplace=True)
df.isnull().sum()
# Out:
# Age                 0
# Sex                 0
# Chest pain type     0
# Trestbps            2
# Restecg             1
# Thalach             1
# Exang               1
# Oldpeak             6
# Slope              17
# Num_diagnosis       0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Age                0
# Sex                0
# Chest pain type    0
# Trestbps           0
# Restecg            0
# Thalach            0
# Exang              0
# Oldpeak            0
# Slope              0
# Num_diagnosis      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'Trestbps', 'Restecg', 'Thalach', 'Exang', 'Oldpeak', 'Slope', 'Num_diagnosis'], dtype='object')

# %%
for i in df.columns:
    if i != 'Oldpeak':
        df[i] = df[i].astype("int64")
    else:
        df[i] = df[i].astype("float64")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 0 to 122
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              105 non-null    int64
#  1   Sex              105 non-null    int64
#  2   Chest pain type  105 non-null    int64
#  3   Trestbps         105 non-null    int64
#  4   Restecg          105 non-null    int64
#  5   Thalach          105 non-null    int64
#  6   Exang            105 non-null    int64
#  7   Oldpeak          105 non-null    float64
#  8   Slope            105 non-null    int64
#  9   Num_diagnosis    105 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 9.0 KB

# %% [markdown]
# # แสดง Attribute Distribution

# %%
df.iloc[:, :-1].hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# # หา Correlation ของ Attribute

# %%
df_corr = df.corr()
df_corr
# Out:
#                       Age       Sex  Chest pain type  Trestbps   Restecg   Thalach     Exang   Oldpeak     Slope  Num_diagnosis
# Age              1.000000 -0.001777         0.000610  0.400573  0.253629 -0.246153  0.029233  0.148219  0.062962      -0.005292
# Sex             -0.001777  1.000000        -0.060330 -0.020265  0.026207 -0.178810  0.010238 -0.105909 -0.020571       0.054720
# Chest pain type  0.000610 -0.060330         1.000000  0.013089 -0.275303 -0.041141  0.308588  0.178275  0.070583       0.264829
# Trestbps         0.400573 -0.020265         0.013089  1.000000  0.121148 -0.172817  0.193831  0.145976 -0.149504       0.147210
# Restecg          0.253629  0.026207        -0.275303  0.121148  1.000000  0.034956 -0.135224 -0.085153 -0.083021       0.046085
# Thalach         -0.246153 -0.178810        -0.041141 -0.172817  0.034956  1.000000 -0.250611  0.172125 -0.142696      -0.276961
# Exang            0.029233  0.010238         0.308588  0.193831 -0.135224 -0.250611  1.000000  0.171847  0.184273       0.173969
# Oldpeak          0.148219 -0.105909         0.178275  0.145976 -0.085153  0.172125  0.171847  1.000000 -0.050542       0.192017
# Slope            0.062962 -0.020571         0.070583 -0.149504 -0.083021 -0.142696  0.184273 -0.050542  1.000000      -0.050858
# Num_diagnosis   -0.005292  0.054720         0.264829  0.147210  0.046085 -0.276961  0.173969  0.192017 -0.050858       1.000000

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(df_corr, annot = True)

# %% [markdown]
# # Train- test split 80/20

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test, y_train, y_test = train_test_split(df.drop("Num_diagnosis", axis=1 ), 
                                                                 df["Num_diagnosis"], test_size=0.2, random_state= 0)

# %% [markdown]
# # Logistic Regression Method

# %%
from sklearn import linear_model
model = linear_model.LogisticRegression(solver='liblinear')
acc_scores =  cross_val_score(model, df.drop("Num_diagnosis", axis=1) , df["Num_diagnosis"], cv=10, scoring="accuracy")
print("Logistic Regression: Mean cross-validation accuracy = %.2f" % acc_scores.mean() )
# Out:
# Logistic Regression: Mean cross-validation accuracy = 0.43

# %% [markdown]
# # k-NN with k = 4

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train, y_train)
(knn.predict(x_test) == y_test).sum()
# Out:
# 3

# %%
knn_pred = knn.predict(x_test)
accuracy = metrics.accuracy_score(y_test, knn_pred)
accuracy
# Out:
# 0.14285714285714285

# %%
scores = cross_val_score (knn,  df.drop("Num_diagnosis", axis=1) , df["Num_diagnosis"], cv =10, scoring = 'accuracy')
scores
# Out:
# array([0.27272727, 0.36363636, 0.27272727, 0.27272727, 0.27272727,
#        0.4       , 0.4       , 0.3       , 0.4       , 0.3       ])

# %%
scores.mean()
# Out:
# 0.3254545454545454

# %% [markdown]
# Confusion Matrix

# %%
conf_mtx_knn = metrics.confusion_matrix(y_test, knn_pred)
conf_mtx_knn
# Out:
# array([[0, 1, 1, 0, 0],
#        [1, 2, 2, 1, 0],
#        [2, 4, 0, 3, 0],
#        [0, 2, 0, 1, 0],
#        [1, 0, 0, 0, 0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.22      0.33      0.27         6
#            2       0.00      0.00      0.00         9
#            3       0.20      0.33      0.25         3
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.14        21
#    macro avg       0.08      0.13      0.10        21
# weighted avg       0.09      0.14      0.11        21

# %% [markdown]
# # SVM Method

# %%
svm = SVC(C=2, gamma='scale', kernel='linear')
svm.fit(x_train, y_train)
svm_pred = svm.predict(x_test)
print(metrics.accuracy_score(svm_pred, y_test) * 100)
# Out:
# 38.095238095238095

# %% [markdown]
# Confusion Matrix

# %%
confusion_matrix(y_test, svm_pred)
# Out:
# array([[0, 1, 1, 0, 0],
#        [0, 6, 0, 0, 0],
#        [0, 6, 2, 1, 0],
#        [0, 3, 0, 0, 0],
#        [0, 1, 0, 0, 0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.35      1.00      0.52         6
#            2       0.67      0.22      0.33         9
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.38        21
#    macro avg       0.20      0.24      0.17        21
# weighted avg       0.39      0.38      0.29        21

# %% [markdown]
# # Decision Tree Method

# %%
decitree = DecisionTreeClassifier()
decitree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
decitree_pred = decitree.predict(x_test)
decitree_pred
# Out:
# array([2, 3, 2, 3, 1, 0, 1, 1, 2, 1, 3, 1, 2, 2, 3, 2, 2, 1, 3, 1, 2])

# %% [markdown]
# Confustion Matrix

# %%
confusion_matrix(y_test, decitree_pred)
# Out:
# array([[0, 0, 1, 1, 0],
#        [0, 3, 2, 1, 0],
#        [1, 1, 5, 2, 0],
#        [0, 2, 0, 1, 0],
#        [0, 1, 0, 0, 0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, decitree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.43      0.50      0.46         6
#            2       0.62      0.56      0.59         9
#            3       0.20      0.33      0.25         3
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.43        21
#    macro avg       0.25      0.28      0.26        21
# weighted avg       0.42      0.43      0.42        21

# %% [markdown]
# # Neural Network (NN) Method

# %%
NN = Sequential()

NN.add(Dense(15 ,activation='relu',input_shape=(x_train.shape[1:])))

# model.add(BatchNormalization())

NN.add(Dense(5, activation='softmax'))

# %%
opt = tf.keras.optimizers.Adam(lr=0.001, decay=0.00001)
# METRICS = [
#       tf.keras.metrics.Accuracy(name='accuracy')
# ]
# tf.keras.metrics.Precision(name='precision'),
# tf.keras.metrics.Recall(name='recall'),
# Compile model
NN.compile(
    loss= "sparse_categorical_crossentropy",
    optimizer=opt,
    metrics='accuracy',
)

# %%
history = NN.fit(x_train, y_train, epochs=30, batch_size = 15)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 0s 777us/step - loss: 72.2601 - accuracy: 0.2381
# Epoch 2/30
# 6/6 [==============================] - 0s 762us/step - loss: 62.8301 - accuracy: 0.2381
# Epoch 3/30
# 6/6 [==============================] - 0s 737us/step - loss: 53.7757 - accuracy: 0.2381
# Epoch 4/30
# 6/6 [==============================] - 0s 694us/step - loss: 45.8344 - accuracy: 0.2500
# Epoch 5/30
# 6/6 [==============================] - 0s 785us/step - loss: 41.1749 - accuracy: 0.2738
# Epoch 6/30
# 6/6 [==============================] - 0s 792us/step - loss: 39.1883 - accuracy: 0.3095
# Epoch 7/30
# 6/6 [==============================] - 0s 790us/step - loss: 36.8557 - accuracy: 0.3452
# Epoch 8/30
# 6/6 [==============================] - 0s 797us/step - loss: 34.0978 - accuracy: 0.3095
# Epoch 9/30
# 6/6 [==============================] - 0s 870us/step - loss: 31.5549 - accuracy: 0.3095
# Epoch 10/30
# 6/6 [==============================] - 0s 853us/step - loss: 28.9230 - accuracy: 0.2738
# Epoch 11/30
# 6/6 [==============================] - 0s 652us/step - loss: 26.8246 - accuracy: 0.2619
# Epoch 12/30
# 6/6 [==============================] - 0s 782us/step - loss: 24.5204 - accuracy: 0.2619
# Epoch 13/30
# 6/6 [==============================] - 0s 748us/step - loss: 22.3767 - accuracy: 0.2738
# Epoch 14/30
# 6/6 [==============================] - 0s 717us/step - loss: 19.9710 - accuracy: 0.2738
# Epoch 15/30
# 6/6 [==============================] - 0s 838us/step - loss: 17.9312 - accuracy: 0.2738
# Epoch 16/30
# 6/6 [==============================] - 0s 742us/step - loss: 15.6304 - accuracy: 0.2738
# Epoch 17/30
# 6/6 [==============================] - 0s 646us/step - loss: 13.6186 - accuracy: 0.2381
# Epoch 18/30
# 6/6 [==============================] - 0s 689us/step - loss: 11.6071 - accuracy: 0.3095
# Epoch 19/30
# 6/6 [==============================] - 0s 717us/step - loss: 10.3106 - accuracy: 0.3095
# Epoch 20/30
# 6/6 [==============================] - 0s 799us/step - loss: 9.7306 - accuracy: 0.3571
# Epoch 21/30
# 6/6 [==============================] - 0s 666us/step - loss: 9.1587 - accuracy: 0.4048
# Epoch 22/30
# 6/6 [==============================] - 0s 694us/step - loss: 8.6629 - accuracy: 0.3810
# Epoch 23/30
# 6/6 [==============================] - 0s 711us/step - loss: 8.3341 - accuracy: 0.2976
# Epoch 24/30
# 6/6 [==============================] - 0s 725us/step - loss: 8.0440 - accuracy: 0.2976
# Epoch 25/30
# 6/6 [==============================] - 0s 761us/step - loss: 7.8788 - accuracy: 0.3452
# Epoch 26/30
# 6/6 [==============================] - 0s 791us/step - loss: 7.6596 - accuracy: 0.3452
# Epoch 27/30
# 6/6 [==============================] - 0s 856us/step - loss: 7.5180 - accuracy: 0.3452
# Epoch 28/30
# 6/6 [==============================] - 0s 662us/step - loss: 7.3390 - accuracy: 0.3452
# Epoch 29/30
# 6/6 [==============================] - 0s 624us/step - loss: 7.1653 - accuracy: 0.3571
# Epoch 30/30
# 6/6 [==============================] - 0s 734us/step - loss: 6.9883 - accuracy: 0.3690

# %%
NN_pred = NN.predict(x_test)
y_pred = tf.argmax(NN_pred, axis=1).numpy()

# %% [markdown]
# Confustion Matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[0, 2, 0, 0, 0],
#        [0, 2, 3, 1, 0],
#        [0, 6, 1, 2, 0],
#        [0, 3, 0, 0, 0],
#        [0, 0, 1, 0, 0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.15      0.33      0.21         6
#            2       0.20      0.11      0.14         9
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.14        21
#    macro avg       0.07      0.09      0.07        21
# weighted avg       0.13      0.14      0.12        21

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# # Train- test split 50/50

# %%
x_train ,x_test, y_train, y_test = train_test_split(df.drop("Num_diagnosis", axis=1 ), 
                                                                 df["Num_diagnosis"], test_size=0.5, random_state= 0)

# %% [markdown]
# # Logistic Regression Method

# %%
model = linear_model.LogisticRegression(solver='liblinear')
acc_scores =  cross_val_score(model, df.drop("Num_diagnosis", axis=1) , df["Num_diagnosis"], cv=10, scoring="accuracy")
print("Logistic Regression: Mean cross-validation accuracy = %.2f" % acc_scores.mean() )
# Out:
# Logistic Regression: Mean cross-validation accuracy = 0.43

# %% [markdown]
# # k-NN with k = 4

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train, y_train)
(knn.predict(x_test) == y_test).sum()
# Out:
# 17

# %%
knn_pred = knn.predict(x_test)
accuracy = metrics.accuracy_score(y_test, knn_pred)
accuracy
# Out:
# 0.32075471698113206

# %%
scores = cross_val_score (knn,  df.drop("Num_diagnosis", axis=1) , df["Num_diagnosis"], cv =10, scoring = 'accuracy')
scores
# Out:
# array([0.27272727, 0.36363636, 0.27272727, 0.27272727, 0.27272727,
#        0.4       , 0.4       , 0.3       , 0.4       , 0.3       ])

# %%
scores.mean()
# Out:
# 0.3254545454545454

# %% [markdown]
# Confusion Matrix

# %%
conf_mtx_knn = metrics.confusion_matrix(y_test, knn_pred)
conf_mtx_knn
# Out:
# array([[ 0,  4,  1,  1,  0],
#        [ 1, 12,  6,  2,  0],
#        [ 0, 10,  2,  3,  0],
#        [ 0,  5,  1,  3,  0],
#        [ 1,  0,  1,  0,  0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.39      0.57      0.46        21
#            2       0.18      0.13      0.15        15
#            3       0.33      0.33      0.33         9
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.32        53
#    macro avg       0.18      0.21      0.19        53
# weighted avg       0.26      0.32      0.28        53

# %% [markdown]
# # SVM Method

# %%
svm = SVC(C=2, gamma='scale', kernel='linear')
svm.fit(x_train, y_train)
svm_pred = svm.predict(x_test)
print(metrics.accuracy_score(svm_pred, y_test) * 100)
# Out:
# 26.41509433962264

# %% [markdown]
# Confusion Matrix

# %%
confusion_matrix(y_test, svm_pred)
# Out:
# array([[0, 5, 0, 1, 0],
#        [1, 8, 8, 4, 0],
#        [0, 4, 6, 4, 1],
#        [1, 3, 3, 0, 2],
#        [0, 1, 0, 1, 0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.38      0.38      0.38        21
#            2       0.35      0.40      0.38        15
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.26        53
#    macro avg       0.15      0.16      0.15        53
# weighted avg       0.25      0.26      0.26        53

# %% [markdown]
# # Decision Tree Method

# %%
decitree = DecisionTreeClassifier()
decitree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
decitree_pred = decitree.predict(x_test)
decitree_pred
# Out:
# array([2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 1, 3, 2, 1, 4, 2, 2, 1, 2, 1, 2, 3,
#        1, 1, 1, 1, 1, 3, 2, 1, 3, 0, 1, 3, 2, 2, 2, 1, 0, 1, 0, 0, 1, 1,
#        2, 2, 1, 3, 2, 2, 2, 2, 1])

# %% [markdown]
# Confustion Matrix

# %%
confusion_matrix(y_test, decitree_pred)
# Out:
# array([[ 1,  2,  3,  0,  0],
#        [ 2, 10,  6,  3,  0],
#        [ 0,  4,  9,  1,  1],
#        [ 1,  3,  3,  2,  0],
#        [ 0,  2,  0,  0,  0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, decitree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.17      0.20         6
#            1       0.48      0.48      0.48        21
#            2       0.43      0.60      0.50        15
#            3       0.33      0.22      0.27         9
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.42        53
#    macro avg       0.30      0.29      0.29        53
# weighted avg       0.39      0.42      0.40        53

# %% [markdown]
# # Neural Network (NN) Method

# %%
NN = Sequential()

NN.add(Dense(15 ,activation='relu',input_shape=(x_train.shape[1:])))

# model.add(BatchNormalization())

NN.add(Dense(5, activation='softmax'))

# %%
opt = tf.keras.optimizers.Adam(lr=0.001, decay=0.00001)
# METRICS = [
#       tf.keras.metrics.Accuracy(name='accuracy')
# ]
# tf.keras.metrics.Precision(name='precision'),
# tf.keras.metrics.Recall(name='recall'),
# Compile model
NN.compile(
    loss= "sparse_categorical_crossentropy",
    optimizer=opt,
    metrics='accuracy',
)

# %%
history = NN.fit(x_train, y_train, epochs=30, batch_size = 15)
# Out:
# Epoch 1/30
# 4/4 [==============================] - 0s 799us/step - loss: 21.5114 - accuracy: 0.0577
# Epoch 2/30
# 4/4 [==============================] - 0s 895us/step - loss: 18.8758 - accuracy: 0.0769
# Epoch 3/30
# 4/4 [==============================] - 0s 841us/step - loss: 17.1866 - accuracy: 0.1538
# Epoch 4/30
# 4/4 [==============================] - 0s 993us/step - loss: 15.8295 - accuracy: 0.1923
# Epoch 5/30
# 4/4 [==============================] - 0s 1ms/step - loss: 14.3273 - accuracy: 0.1923
# Epoch 6/30
# 4/4 [==============================] - 0s 961us/step - loss: 13.4741 - accuracy: 0.2115
# Epoch 7/30
# 4/4 [==============================] - 0s 832us/step - loss: 12.9278 - accuracy: 0.2308
# Epoch 8/30
# 4/4 [==============================] - 0s 761us/step - loss: 11.8700 - accuracy: 0.2692
# Epoch 9/30
# 4/4 [==============================] - 0s 808us/step - loss: 11.0367 - accuracy: 0.2500
# Epoch 10/30
# 4/4 [==============================] - 0s 719us/step - loss: 10.3404 - accuracy: 0.2115
# Epoch 11/30
# 4/4 [==============================] - 0s 725us/step - loss: 9.5950 - accuracy: 0.1731
# Epoch 12/30
# 4/4 [==============================] - 0s 804us/step - loss: 8.5439 - accuracy: 0.2308
# Epoch 13/30
# 4/4 [==============================] - 0s 714us/step - loss: 7.7931 - accuracy: 0.2500
# Epoch 14/30
# 4/4 [==============================] - 0s 727us/step - loss: 7.0452 - accuracy: 0.2308
# Epoch 15/30
# 4/4 [==============================] - 0s 919us/step - loss: 6.0912 - accuracy: 0.2308
# Epoch 16/30
# 4/4 [==============================] - 0s 739us/step - loss: 5.3915 - accuracy: 0.2115
# Epoch 17/30
# 4/4 [==============================] - 0s 768us/step - loss: 4.4000 - accuracy: 0.2115
# Epoch 18/30
# 4/4 [==============================] - 0s 895us/step - loss: 3.6528 - accuracy: 0.2308
# Epoch 19/30
# 4/4 [==============================] - 0s 736us/step - loss: 2.8091 - accuracy: 0.2692
# Epoch 20/30
# 4/4 [==============================] - 0s 835us/step - loss: 2.5942 - accuracy: 0.2115
# Epoch 21/30
# 4/4 [==============================] - 0s 790us/step - loss: 2.5245 - accuracy: 0.2692
# Epoch 22/30
# 4/4 [==============================] - 0s 829us/step - loss: 2.3622 - accuracy: 0.2115
# Epoch 23/30
# 4/4 [==============================] - 0s 719us/step - loss: 2.3063 - accuracy: 0.3077
# Epoch 24/30
# 4/4 [==============================] - 0s 835us/step - loss: 2.2296 - accuracy: 0.2885
# Epoch 25/30
# 4/4 [==============================] - 0s 898us/step - loss: 2.1609 - accuracy: 0.2308
# Epoch 26/30
# 4/4 [==============================] - 0s 737us/step - loss: 2.1039 - accuracy: 0.2500
# Epoch 27/30
# 4/4 [==============================] - 0s 705us/step - loss: 2.0349 - accuracy: 0.2500
# Epoch 28/30
# 4/4 [==============================] - 0s 805us/step - loss: 2.0022 - accuracy: 0.2500
# Epoch 29/30
# 4/4 [==============================] - 0s 740us/step - loss: 1.9427 - accuracy: 0.2885
# Epoch 30/30
# 4/4 [==============================] - 0s 655us/step - loss: 1.8917 - accuracy: 0.2692

# %%
NN_pred = NN.predict(x_test)
y_pred = tf.argmax(NN_pred, axis=1).numpy()

# %% [markdown]
# Confustion Matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 0,  2,  4,  0,  0],
#        [ 1,  7, 11,  2,  0],
#        [ 0,  4,  7,  4,  0],
#        [ 2,  5,  0,  2,  0],
#        [ 0,  0,  0,  2,  0]])

# %% [markdown]
# Presicion & Recall

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.39      0.33      0.36        21
#            2       0.32      0.47      0.38        15
#            3       0.20      0.22      0.21         9
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.30        53
#    macro avg       0.18      0.20      0.19        53
# weighted avg       0.28      0.30      0.29        53

# %% [markdown]
# # Reference

# %% [markdown]
# Detrano, R., Janosi, A., Steinbrunn, W., Pfisterer, M., Schmid, J., Sandhu, S., Guppy, K., Lee, S., & Froelicher, V. (1989). International application of a new probability algorithm for the diagnosis of coronary artery disease. American Journal of Cardiology, 64,304--310.
# [Web Link]
#
# David W. Aha & Dennis Kibler. "Instance-based prediction of heart-disease presence with the Cleveland database."
# [Web Link]
#
# Gennari, J.H., Langley, P, & Fisher, D. (1989). Models of incremental concept formation. Artificial Intelligence, 40, 11--61.
# [Web Link]

# %% [markdown]
# # END
